# %%
game_tree = {
    "M1": {"type": "max", "children": ["C1", "C2", "C3", "C4"]},
    "C1": {"type": "chance", "children": [{"node": "N1", "probability": 0.2}, {"node": "N2", "probability": 0.8}]},
    "C2": {"type": "chance", "children": [{"node": "N3", "probability": 0.6}, {"node": "N4", "probability": 0.4}]},
    "C3": {"type": "chance", "children": [{"node": "N5", "probability": 0.3}, {"node": "N6", "probability": 0.7}]},
    "C4": {"type": "chance", "children": [{"node": "N7", "probability": 0.9}, {"node": "N8", "probability": 0.1}]},
    "N1": {"type": "min", "children": ["C5", "C6"]},
    "N2": {"type": "min", "children": ["C7"]},
    "N3": {"type": "min", "children": ["C8"]},
    "N4": {"type": "min", "children": ["C9"]},
    "N5": {"type": "min", "children": ["C10"]},
    "N6": {"type": "min", "children": ["C11"]},
    "N7": {"type": "min", "children": ["C12"]},
    "N8": {"type": "min", "children": ["C13"]},
    "C5": {"type": "chance", "children": [{"node": "2", "probability": 0.9}, {"node": "-22", "probability": 0.1}]},
    "C6": {"type": "chance", "children": [{"node": "M9", "probability": 0.3}, {"node": "M10", "probability": 0.7}]},
    "C7": {"type": "chance", "children": [{"node": "15", "probability": 0.4}, {"node": "9", "probability": 0.6}]},
    "C8": {"type": "chance", "children": [{"node": "1", "probability": 0.3}, {"node": "M11", "probability": 0.7}]},
    "C9": {"type": "chance", "children": [{"node": "-12", "probability": 0.9}, {"node": "3", "probability": 0.1}]},
    "C10": {"type": "chance", "children": [{"node": "5", "probability": 0.4}, {"node": "M12", "probability": 0.6}]},
    "C11": {"type": "chance", "children": [{"node": "-5", "probability": 0.6}, {"node": "11", "probability": 0.4}]},
    "C12": {"type": "chance", "children": [{"node": "-22", "probability": 0.3}, {"node": "M13", "probability": 0.7}]},
    "C13": {"type": "chance", "children": [{"node": "2", "probability": 0.2}, {"node": "4", "probability": 0.8}]},
    "M9": {"type": "max", "children": ["C14"]},
    "M10": {"type": "max", "children": ["C15"]},
    "M11": {"type": "max", "children": ["C16", "C17"]},
    "M12": {"type": "max", "children": ["C18"]},
    "M13": {"type": "max", "children": ["C19", "C20"]},
    "C14": {"type": "chance", "children": [{"node": "11", "probability": 0.7}, {"node": "-5", "probability": 0.3}]},
    "C15": {"type": "chance", "children": [{"node": "0", "probability": 0.8}, {"node": "10", "probability": 0.2}]},
    "C16": {"type": "chance", "children": [{"node": "-9", "probability": 0.5}, {"node": "9", "probability": 0.5}]},
    "C17": {"type": "chance", "children": [{"node": "13", "probability": 0.6}, {"node": "-2", "probability": 0.4}]},
    "C18": {"type": "chance", "children": [{"node": "-13", "probability": 0.1}, {"node": "1", "probability": 0.9}]},
    "C19": {"type": "chance", "children": [{"node": "5", "probability": 0.1}, {"node": "7", "probability": 0.9}]},
    "C20": {"type": "chance", "children": [{"node": "9", "probability": 0.6}, {"node": "10", "probability": 0.4}]},
    "2": {"utility": 2},
    "-22": {"utility": -22},
    "15": {"utility": 15},
    "9": {"utility": 9},
    "1": {"utility": 1},
    "-12": {"utility": -12},
    "3": {"utility": 3},
    "5": {"utility": 5},
    "-5": {"utility": -5},
    "11": {"utility": 11},
    "4": {"utility": 4},
    "0": {"utility": 0},
    "-9": {"utility": -9},
    "13": {"utility": 13},
    "-2": {"utility": -2},
    "-13": {"utility": -13},
    "7": {"utility": 7},
    "10": {"utility": 10}
}

# %%
def expectimax(node_name):
    node = game_tree[node_name]

    # Base Case: Terminal node with a static evaluation
    if "utility" in node:
        print(f"Terminal node {node_name} with utility {node['utility']}")
        return node["utility"]

    node_type = node["type"]

    # max node: choose the highest value among children
    if node_type == "max":
        print(f"\nEvaluating MAX node {node_name} with children {node['children']}")
        child_values = []
        for child in node["children"]:
            val = expectimax(child)
            child_values.append(val)
        best_value = max(child_values)
        print(f"MAX node {node_name} child utilities: {child_values} --> selected {best_value}")
        return best_value

    # min node: choose the lowest value among children
    elif node_type == "min":
        print(f"\nEvaluating MIN node {node_name} with children {node['children']}")
        child_values = []
        for child in node["children"]:
            val = expectimax(child)
            child_values.append(val)
        best_value = min(child_values)
        print(f"MIN node {node_name} child utilities: {child_values} --> selected {best_value}")
        return best_value

    # chance node: compute the weighted average of children
    elif node_type == "chance":
        print(f"\nEvaluating CHANCE node {node_name} with outcomes:")
        expected_value = 0
        for outcome in node["children"]:
            child_node = outcome["node"]
            probability = outcome["probability"]
            child_val = expectimax(child_node)
            weighted_val = probability * child_val
            print(f"  Outcome node {child_node} with probability {probability} yields {child_val} (weighted: {weighted_val})")
            expected_value += weighted_val
        print(f"CHANCE node {node_name} expected value: {expected_value}")
        return expected_value

    else:
        raise ValueError(f"Unknown node type: {node_type}")

# Example: Compute the expected utility from the root node "A1"
result = expectimax("A1")
print("\nOptimal expected utility from:", result)
# Out:
# Evaluating MAX node A1 with children ['C1', 'C2', 'C3', 'C4']
#
# Evaluating CHANCE node C1 with outcomes:
#
# Evaluating MIN node B1 with children ['C5', 'C6']
#
# Evaluating CHANCE node C5 with outcomes:
#
# Evaluating MAX node A2 with children ['t28']
# Terminal node t28 with utility 13
# MAX node A2 child utilities: [13] --> selected 13
#   Outcome node A2 with probability 0.5 yields 13 (weighted: 6.5)
# Terminal node t1 with utility 28
#   Outcome node t1 with probability 0.5 yields 28 (weighted: 14.0)
# CHANCE node C5 expected value: 20.5
#
# Evaluating CHANCE node C6 with outcomes:
#
# Evaluating MAX node A3 with children ['t29', 't30']
# Terminal node t29 with utility 10
# Terminal node t30 with utility 17
# MAX node A3 child utilities: [10, 17] --> selected 17
#   Outcome node A3 with probability 0.1 yields 17 (weighted: 1.7000000000000002)
# Terminal node t2 with utility 19
#   Outcome node t2 with probability 0.9 yields 19 (weighted: 17.1)
# CHANCE node C6 expected value: 18.8
# MIN node B1 child utilities: [20.5, 18.8] --> selected 18.8
#   Outcome node B1 with probability 0.5 yields 18.8 (weighted: 9.4)
#
# Evaluating MIN node B2 with children ['C7', 'C8']
#
# Evaluating CHANCE node C7 with outcomes:
# Terminal node t3 with utility 16
#   Outcome node t3 with probability 0.5 yields 16 (weighted: 8.0)
# Terminal node t4 with utility 17
#   Outcome node t4 with probability 0.5 yields 17 (weighted: 8.5)
# CHANCE node C7 expected value: 16.5
#
# Evaluating CHANCE node C8 with outcomes:
# Terminal node t5 with utility 17
#   Outcome node t5 with probability 0.1 yields 17 (weighted: 1.7000000000000002)
#
# Evaluating MAX node A4 with children ['t31', 't32', 't33']
# Terminal node t31 with utility 10
# Terminal node t32 with utility 12
# Terminal node t33 with utility 8
# MAX node A4 child utilities: [10, 12, 8] --> selected 12
#   Outcome node A4 with probability 0.9 yields 12 (weighted: 10.8)
# CHANCE node C8 expected value: 12.5
# MIN node B2 child utilities: [16.5, 12.5] --> selected 12.5
#   Outcome node B2 with probability 0.5 yields 12.5 (weighted: 6.25)
# CHANCE node C1 expected value: 15.65
#
# Evaluating CHANCE node C2 with outcomes:
#
# Evaluating MIN node B3 with children ['C9', 'C10']
#
# Evaluating CHANCE node C9 with outcomes:
# Terminal node t6 with utility 5
#   Outcome node t6 with probability 0.9 yields 5 (weighted: 4.5)
# Terminal node t7 with utility 28
#   Outcome node t7 with probability 0.1 yields 28 (weighted: 2.8000000000000003)
# CHANCE node C9 expected value: 7.300000000000001
#
# Evaluating CHANCE node C10 with outcomes:
# Terminal node t8 with utility 1
#   Outcome node t8 with probability 0.5 yields 1 (weighted: 0.5)
# Terminal node t9 with utility 28
#   Outcome node t9 with probability 0.5 yields 28 (weighted: 14.0)
# CHANCE node C10 expected value: 14.5
# MIN node B3 child utilities: [7.300000000000001, 14.5] --> selected 7.300000000000001
#   Outcome node B3 with probability 0.1 yields 7.300000000000001 (weighted: 0.7300000000000001)
#
# Evaluating MIN node B4 with children ['C11', 'C12']
#
# Evaluating CHANCE node C11 with outcomes:
#
# Evaluating MAX node A5 with children ['t34', 't35', 't36']
# Terminal node t34 with utility 2
# Terminal node t35 with utility 20
# Terminal node t36 with utility 13
# MAX node A5 child utilities: [2, 20, 13] --> selected 20
#   Outcome node A5 with probability 0.1 yields 20 (weighted: 2.0)
# Terminal node t10 with utility 6
#   Outcome node t10 with probability 0.9 yields 6 (weighted: 5.4)
# CHANCE node C11 expected value: 7.4
#
# Evaluating CHANCE node C12 with outcomes:
# Terminal node t11 with utility 26
#   Outcome node t11 with probability 0.5 yields 26 (weighted: 13.0)
# Terminal node t12 with utility 1
#   Outcome node t12 with probability 0.5 yields 1 (weighted: 0.5)
# CHANCE node C12 expected value: 13.5
# MIN node B4 child utilities: [7.4, 13.5] --> selected 7.4
#   Outcome node B4 with probability 0.9 yields 7.4 (weighted: 6.66)
# CHANCE node C2 expected value: 7.390000000000001
#
# Evaluating CHANCE node C3 with outcomes:
#
# Evaluating MIN node B5 with children ['C13', 'C14']
#
# Evaluating CHANCE node C13 with outcomes:
# Terminal node t13 with utility 11
#   Outcome node t13 with probability 0.5 yields 11 (weighted: 5.5)
#
# Evaluating MAX node A6 with children ['t37', 't38']
# Terminal node t37 with utility 20
# Terminal node t38 with utility 22
# MAX node A6 child utilities: [20, 22] --> selected 22
#   Outcome node A6 with probability 0.5 yields 22 (weighted: 11.0)
# CHANCE node C13 expected value: 16.5
#
# Evaluating CHANCE node C14 with outcomes:
# Terminal node t14 with utility 22
#   Outcome node t14 with probability 0.9 yields 22 (weighted: 19.8)
# Terminal node t15 with utility 13
#   Outcome node t15 with probability 0.1 yields 13 (weighted: 1.3)
# CHANCE node C14 expected value: 21.1
# MIN node B5 child utilities: [16.5, 21.1] --> selected 16.5
#   Outcome node B5 with probability 0.5 yields 16.5 (weighted: 8.25)
#
# Evaluating MIN node B6 with children ['C15', 'C16']
#
# Evaluating CHANCE node C15 with outcomes:
# Terminal node t16 with utility 11
#   Outcome node t16 with probability 0.1 yields 11 (weighted: 1.1)
# Terminal node t17 with utility 13
#   Outcome node t17 with probability 0.9 yields 13 (weighted: 11.700000000000001)
# CHANCE node C15 expected value: 12.8
#
# Evaluating CHANCE node C16 with outcomes:
# Terminal node t18 with utility 12
#   Outcome node t18 with probability 0.9 yields 12 (weighted: 10.8)
# Terminal node t19 with utility 13
#   Outcome node t19 with probability 0.1 yields 13 (weighted: 1.3)
# CHANCE node C16 expected value: 12.100000000000001
# MIN node B6 child utilities: [12.8, 12.100000000000001] --> selected 12.100000000000001
#   Outcome node B6 with probability 0.5 yields 12.100000000000001 (weighted: 6.050000000000001)
# CHANCE node C3 expected value: 14.3
#
# Evaluating CHANCE node C4 with outcomes:
#
# Evaluating MIN node B7 with children ['C17', 'C18']
#
# Evaluating CHANCE node C17 with outcomes:
# Terminal node t20 with utility 20
#   Outcome node t20 with probability 0.9 yields 20 (weighted: 18.0)
# Terminal node t21 with utility 17
#   Outcome node t21 with probability 0.1 yields 17 (weighted: 1.7000000000000002)
# CHANCE node C17 expected value: 19.7
#
# Evaluating CHANCE node C18 with outcomes:
# Terminal node t22 with utility 9
#   Outcome node t22 with probability 0.5 yields 9 (weighted: 4.5)
#
# Evaluating MAX node A7 with children ['t39', 't40']
# Terminal node t39 with utility 28
# Terminal node t40 with utility 21
# MAX node A7 child utilities: [28, 21] --> selected 28
#   Outcome node A7 with probability 0.5 yields 28 (weighted: 14.0)
# CHANCE node C18 expected value: 18.5
# MIN node B7 child utilities: [19.7, 18.5] --> selected 18.5
#   Outcome node B7 with probability 0.5 yields 18.5 (weighted: 9.25)
#
# Evaluating MIN node B8 with children ['C19']
#
# Evaluating CHANCE node C19 with outcomes:
# Terminal node t23 with utility 20
#   Outcome node t23 with probability 0.9 yields 20 (weighted: 18.0)
# Terminal node t24 with utility 27
#   Outcome node t24 with probability 0.1 yields 27 (weighted: 2.7)
# CHANCE node C19 expected value: 20.7
# MIN node B8 child utilities: [20.7] --> selected 20.7
#   Outcome node B8 with probability 0.1 yields 20.7 (weighted: 2.07)
#
# Evaluating MIN node B9 with children ['C20', 'C21']
#
# Evaluating CHANCE node C20 with outcomes:
# Terminal node t25 with utility 6
#   Outcome node t25 with probability 0.5 yields 6 (weighted: 3.0)
#
# Evaluating MAX node A8 with children ['t41', 't42', 't43']
# Terminal node t41 with utility 9
# Terminal node t42 with utility 3
# Terminal node t43 with utility 5
# MAX node A8 child utilities: [9, 3, 5] --> selected 9
#   Outcome node A8 with probability 0.5 yields 9 (weighted: 4.5)
# CHANCE node C20 expected value: 7.5
#
# Evaluating CHANCE node C21 with outcomes:
# Terminal node t26 with utility 15
#   Outcome node t26 with probability 0.9 yields 15 (weighted: 13.5)
# Terminal node t27 with utility 20
#   Outcome node t27 with probability 0.1 yields 20 (weighted: 2.0)
# CHANCE node C21 expected value: 15.5
# MIN node B9 child utilities: [7.5, 15.5] --> selected 7.5
#   Outcome node B9 with probability 0.4 yields 7.5 (weighted: 3.0)
# CHANCE node C4 expected value: 14.32
# MAX node A1 child utilities: [15.65, 7.390000000000001, 14.3, 14.32] --> selected 15.65
#
# Optimal expected utility from: 15.65
