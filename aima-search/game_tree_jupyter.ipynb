# %%
game_tree = {
    "A1": {"player": "Anne", "children": ["E1", "E2", "E3", "E4"]},
    "E1": {"player": "Ellen", "children": ["M1", "M2"]},
    "E2": {"player": "Ellen", "children": ["M3", "M4"]},
    "E3": {"player": "Ellen", "children": ["M5", "M6"]},
    "E4": {"player": "Ellen", "children": ["M7", "M8"]},
    "M1": {"player": "Monica", "children": ["N1", "N2"]},
    "M2": {"player": "Monica", "children": ["N3"]},
    "M3": {"player": "Monica", "children": ["N4", "N5"]},
    "M4": {"player": "Monica", "children": ["N6", "N7"]},
    "M5": {"player": "Monica", "children": ["N8"]},
    "M6": {"player": "Monica", "children": ["N9","N10"]},
    "M7": {"player": "Monica", "children": ["N11"]},
    "M8": {"player": "Monica", "children": ["N12","N13"]},
    "N1": {"player": "Nicole", "children": ["v1", "A2"]},
    "N2": {"player": "Nicole", "children": ["v2"]},
    "N3": {"player": "Nicole", "children": ["v3", "A3"]},
    "N4": {"player": "Nicole", "children": ["v4"]},
    "N5": {"player": "Nicole", "children": ["v5"]},
    "N6": {"player": "Nicole", "children": ["A4"]},
    "N7": {"player": "Nicole", "children": ["v6"]},
    "N8": {"player": "Nicole", "children": ["A5", "v7"]},
    "N9": {"player": "Nicole", "children": ["v8"]},
    "N10": {"player": "Nicole", "children": ["v9"]},
    "N11": {"player": "Nicole", "children": ["v10"]},
    "N12": {"player": "Nicole", "children": ["v11"]},
    "N13": {"player": "Nicole", "children": ["A6", "v12"]},
    "A2": {"player": "Anne", "children": ["v13", "E5"]},
    "A3": {"player": "Anne", "children": ["E6", "v14"]},
    "A4": {"player": "Anne", "children": ["v15"]},
    "A5": {"player": "Anne", "children": ["E7", "v16"]},
    "A6": {"player": "Anne", "children": ["v17"]},
    "E5": {"player": "Ellen", "children": ["M9", "v18"]},
    "E6": {"player": "Ellen", "children": ["v19"]},
    "E7": {"player": "Ellen", "children": ["M10", "v20"]},
    "M9": {"player": "Monica", "children": ["v21"]},
    "M10": {"player": "Monica", "children": ["v22"]}
}

game_tree.update({
    "v1": {"utility": (20, 30, 10, 6)}
})

# %%
# Order of players in the utility tuple
players = ["Anne", "Ellen", "Monica", "Nicole"]

def minimax(node_name):
    node = game_tree[node_name]

    # Base Case: Terminal node
    if "utility" in node:
        print(f"Terminal node {node_name}: utility = {node['utility']}")
        return node["utility"]

    current_player = node["player"]
    player_index = players.index(current_player)
    print(f"\nEvaluating node {node_name} for player {current_player}")

    # Evaluate each child and store the (child_name, utility) tuple.
    child_results = []
    for child in node["children"]:
        child_util = minimax(child)
        child_results.append((child, child_util))

    # Print the computed utilities for all child nodes.
    print(f"\nFor node {node_name}, computed child utilities:")
    for child, util in child_results:
        print(f"  Child node {child}: utility = {util}")

    # Select the child that gives the maximum utility for the current player.
    best_child, best_util = max(child_results, key=lambda tup: tup[1][player_index])
    print(f"Node {node_name} (player {current_player}) selects child {best_child} with utility {best_util}\n")

    return best_util

# Example: Compute the utility at the root node "A1"
result = minimax("A1")
print("Optimal utility from:", result)
# Out:
# Evaluating node A1 for player Anne
#
# Evaluating node E1 for player Ellen
#
# Evaluating node M1 for player Monica
#
# Evaluating node N1 for player Nicole
# Terminal node v1: utility = (20, 30, 10, 6)
#
# Evaluating node A2 for player Anne
# Terminal node v13: utility = (1, 9, 8, 15)
#
# Evaluating node E5 for player Ellen
#
# Evaluating node M9 for player Monica
# Terminal node v21: utility = (5, 7, 2, 1)
#
# For node M9, computed child utilities:
#   Child node v21: utility = (5, 7, 2, 1)
# Node M9 (player Monica) selects child v21 with utility (5, 7, 2, 1)
#
# Terminal node v18: utility = (20, 10, 5, 9)
#
# For node E5, computed child utilities:
#   Child node M9: utility = (5, 7, 2, 1)
#   Child node v18: utility = (20, 10, 5, 9)
# Node E5 (player Ellen) selects child v18 with utility (20, 10, 5, 9)
#
#
# For node A2, computed child utilities:
#   Child node v13: utility = (1, 9, 8, 15)
#   Child node E5: utility = (20, 10, 5, 9)
# Node A2 (player Anne) selects child E5 with utility (20, 10, 5, 9)
#
#
# For node N1, computed child utilities:
#   Child node v1: utility = (20, 30, 10, 6)
#   Child node A2: utility = (20, 10, 5, 9)
# Node N1 (player Nicole) selects child A2 with utility (20, 10, 5, 9)
#
#
# Evaluating node N2 for player Nicole
# Terminal node v2: utility = (15, 2, 10, 5)
#
# For node N2, computed child utilities:
#   Child node v2: utility = (15, 2, 10, 5)
# Node N2 (player Nicole) selects child v2 with utility (15, 2, 10, 5)
#
#
# For node M1, computed child utilities:
#   Child node N1: utility = (20, 10, 5, 9)
#   Child node N2: utility = (15, 2, 10, 5)
# Node M1 (player Monica) selects child N2 with utility (15, 2, 10, 5)
#
#
# Evaluating node M2 for player Monica
#
# Evaluating node N3 for player Nicole
# Terminal node v3: utility = (14, 20, 1, 2)
#
# Evaluating node A3 for player Anne
#
# Evaluating node E6 for player Ellen
# Terminal node v19: utility = (8, 12, 4, 6)
#
# For node E6, computed child utilities:
#   Child node v19: utility = (8, 12, 4, 6)
# Node E6 (player Ellen) selects child v19 with utility (8, 12, 4, 6)
#
# Terminal node v14: utility = (6, 18, 8, 9)
#
# For node A3, computed child utilities:
#   Child node E6: utility = (8, 12, 4, 6)
#   Child node v14: utility = (6, 18, 8, 9)
# Node A3 (player Anne) selects child E6 with utility (8, 12, 4, 6)
#
#
# For node N3, computed child utilities:
#   Child node v3: utility = (14, 20, 1, 2)
#   Child node A3: utility = (8, 12, 4, 6)
# Node N3 (player Nicole) selects child A3 with utility (8, 12, 4, 6)
#
#
# For node M2, computed child utilities:
#   Child node N3: utility = (8, 12, 4, 6)
# Node M2 (player Monica) selects child N3 with utility (8, 12, 4, 6)
#
#
# For node E1, computed child utilities:
#   Child node M1: utility = (15, 2, 10, 5)
#   Child node M2: utility = (8, 12, 4, 6)
# Node E1 (player Ellen) selects child M2 with utility (8, 12, 4, 6)
#
#
# Evaluating node E2 for player Ellen
#
# Evaluating node M3 for player Monica
#
# Evaluating node N4 for player Nicole
# Terminal node v4: utility = (12, 6, 30, 8)
#
# For node N4, computed child utilities:
#   Child node v4: utility = (12, 6, 30, 8)
# Node N4 (player Nicole) selects child v4 with utility (12, 6, 30, 8)
#
#
# Evaluating node N5 for player Nicole
# Terminal node v5: utility = (40, 5, 10, 30)
#
# For node N5, computed child utilities:
#   Child node v5: utility = (40, 5, 10, 30)
# Node N5 (player Nicole) selects child v5 with utility (40, 5, 10, 30)
#
#
# For node M3, computed child utilities:
#   Child node N4: utility = (12, 6, 30, 8)
#   Child node N5: utility = (40, 5, 10, 30)
# Node M3 (player Monica) selects child N4 with utility (12, 6, 30, 8)
#
#
# Evaluating node M4 for player Monica
#
# Evaluating node N6 for player Nicole
#
# Evaluating node A4 for player Anne
# Terminal node v15: utility = (2, 25, 3, 30)
#
# For node A4, computed child utilities:
#   Child node v15: utility = (2, 25, 3, 30)
# Node A4 (player Anne) selects child v15 with utility (2, 25, 3, 30)
#
#
# For node N6, computed child utilities:
#   Child node A4: utility = (2, 25, 3, 30)
# Node N6 (player Nicole) selects child A4 with utility (2, 25, 3, 30)
#
#
# Evaluating node N7 for player Nicole
# Terminal node v6: utility = (4, 16, 1, 15)
#
# For node N7, computed child utilities:
#   Child node v6: utility = (4, 16, 1, 15)
# Node N7 (player Nicole) selects child v6 with utility (4, 16, 1, 15)
#
#
# For node M4, computed child utilities:
#   Child node N6: utility = (2, 25, 3, 30)
#   Child node N7: utility = (4, 16, 1, 15)
# Node M4 (player Monica) selects child N6 with utility (2, 25, 3, 30)
#
#
# For node E2, computed child utilities:
#   Child node M3: utility = (12, 6, 30, 8)
#   Child node M4: utility = (2, 25, 3, 30)
# Node E2 (player Ellen) selects child M4 with utility (2, 25, 3, 30)
#
#
# Evaluating node E3 for player Ellen
#
# Evaluating node M5 for player Monica
#
# Evaluating node N8 for player Nicole
#
# Evaluating node A5 for player Anne
#
# Evaluating node E7 for player Ellen
#
# Evaluating node M10 for player Monica
# Terminal node v22: utility = (4, 14, 2, 1)
#
# For node M10, computed child utilities:
#   Child node v22: utility = (4, 14, 2, 1)
# Node M10 (player Monica) selects child v22 with utility (4, 14, 2, 1)
#
# Terminal node v20: utility = (18, 10, 5, 9)
#
# For node E7, computed child utilities:
#   Child node M10: utility = (4, 14, 2, 1)
#   Child node v20: utility = (18, 10, 5, 9)
# Node E7 (player Ellen) selects child M10 with utility (4, 14, 2, 1)
#
# Terminal node v16: utility = (2, 22, 0, 12)
#
# For node A5, computed child utilities:
#   Child node E7: utility = (4, 14, 2, 1)
#   Child node v16: utility = (2, 22, 0, 12)
# Node A5 (player Anne) selects child E7 with utility (4, 14, 2, 1)
#
# Terminal node v7: utility = (10, 33, 23, 0)
#
# For node N8, computed child utilities:
#   Child node A5: utility = (4, 14, 2, 1)
#   Child node v7: utility = (10, 33, 23, 0)
# Node N8 (player Nicole) selects child A5 with utility (4, 14, 2, 1)
#
#
# For node M5, computed child utilities:
#   Child node N8: utility = (4, 14, 2, 1)
# Node M5 (player Monica) selects child N8 with utility (4, 14, 2, 1)
#
#
# Evaluating node M6 for player Monica
#
# Evaluating node N9 for player Nicole
# Terminal node v8: utility = (20, 10, 30, 12)
#
# For node N9, computed child utilities:
#   Child node v8: utility = (20, 10, 30, 12)
# Node N9 (player Nicole) selects child v8 with utility (20, 10, 30, 12)
#
#
# Evaluating node N10 for player Nicole
# Terminal node v9: utility = (16, 90, 25, 100)
#
# For node N10, computed child utilities:
#   Child node v9: utility = (16, 90, 25, 100)
# Node N10 (player Nicole) selects child v9 with utility (16, 90, 25, 100)
#
#
# For node M6, computed child utilities:
#   Child node N9: utility = (20, 10, 30, 12)
#   Child node N10: utility = (16, 90, 25, 100)
# Node M6 (player Monica) selects child N9 with utility (20, 10, 30, 12)
#
#
# For node E3, computed child utilities:
#   Child node M5: utility = (4, 14, 2, 1)
#   Child node M6: utility = (20, 10, 30, 12)
# Node E3 (player Ellen) selects child M5 with utility (4, 14, 2, 1)
#
#
# Evaluating node E4 for player Ellen
#
# Evaluating node M7 for player Monica
#
# Evaluating node N11 for player Nicole
# Terminal node v10: utility = (1, 5, 2, 20)
#
# For node N11, computed child utilities:
#   Child node v10: utility = (1, 5, 2, 20)
# Node N11 (player Nicole) selects child v10 with utility (1, 5, 2, 20)
#
#
# For node M7, computed child utilities:
#   Child node N11: utility = (1, 5, 2, 20)
# Node M7 (player Monica) selects child N11 with utility (1, 5, 2, 20)
#
#
# Evaluating node M8 for player Monica
#
# Evaluating node N12 for player Nicole
# Terminal node v11: utility = (18, 10, 5, 20)
#
# For node N12, computed child utilities:
#   Child node v11: utility = (18, 10, 5, 20)
# Node N12 (player Nicole) selects child v11 with utility (18, 10, 5, 20)
#
#
# Evaluating node N13 for player Nicole
#
# Evaluating node A6 for player Anne
# Terminal node v17: utility = (18, 21, 35, 22)
#
# For node A6, computed child utilities:
#   Child node v17: utility = (18, 21, 35, 22)
# Node A6 (player Anne) selects child v17 with utility (18, 21, 35, 22)
#
# Terminal node v12: utility = (25, 20, 25, 8)
#
# For node N13, computed child utilities:
#   Child node A6: utility = (18, 21, 35, 22)
#   Child node v12: utility = (25, 20, 25, 8)
# Node N13 (player Nicole) selects child A6 with utility (18, 21, 35, 22)
#
#
# For node M8, computed child utilities:
#   Child node N12: utility = (18, 10, 5, 20)
#   Child node N13: utility = (18, 21, 35, 22)
# Node M8 (player Monica) selects child N13 with utility (18, 21, 35, 22)
#
#
# For node E4, computed child utilities:
#   Child node M7: utility = (1, 5, 2, 20)
#   Child node M8: utility = (18, 21, 35, 22)
# Node E4 (player Ellen) selects child M8 with utility (18, 21, 35, 22)
#
#
# For node A1, computed child utilities:
#   Child node E1: utility = (8, 12, 4, 6)
#   Child node E2: utility = (2, 25, 3, 30)
#   Child node E3: utility = (4, 14, 2, 1)
#   Child node E4: utility = (18, 21, 35, 22)
# Node A1 (player Anne) selects child E4 with utility (18, 21, 35, 22)
#
# Optimal utility from: (18, 21, 35, 22)
